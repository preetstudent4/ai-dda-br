# %%
import pandas as pd
from IPython.display import display

# %%
# pubg_df = pd.read_csv(r"C:\\Users\\Owner\\Downloads\\10.tsv", sep="\t")
df1_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\0.tsv", sep="\t")
df2_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\1.tsv", sep="\t")
df3_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\2.tsv", sep="\t")
df4_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\3.tsv", sep="\t")
df5_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\4.tsv", sep="\t")
df6_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\5.tsv", sep="\t")
df7_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\6.tsv", sep="\t")
df8_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\7.tsv", sep="\t")
df9_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\8.tsv", sep="\t")
df10_skillChallenge = pd.read_csv(r"C:\\Users\\Owner\\Desktop\\pubg_data\\dataset\\Skill-Challenge\\phase-wise-features\\9.tsv", sep="\t")
# print(pubg_df.head())

# %%
# display(df1_skillChallenge.head())
# print(df1_skillChallenge.info)
df1_skillChallenge['map_name'].value_counts()
df1_skillChallenge['split'].value_counts()
# Out:
# split
# train    3335228
# test      389301
# val       384778
# Name: count, dtype: int64

# %%
display(df2_skillChallenge.head())
# Out:
#     match_id  snapshot  elapsed_time  player_id  player_name  team_id  \
# 0  match_959        52      0.294464  pid_79318  pname_22267        0
# 1  match_959        52      0.294464  pid_51079  pname_22267        0
# 2  match_959        52      0.294464  pid_73348  pname_22267        0
# 3  match_959        52      0.294464  pid_88538  pname_22267        0
# 4  match_959        52      0.294464  pid_50432  pname_22267        0
#
#        loc_x      loc_y      loc_z  health  ...  num_alive_teams  \
# 0  6272.7840  5910.0474  76.699280  1600.0  ...         0.714286
# 1  3915.7244  6094.1626  82.318090  1600.0  ...         0.714286
# 2  3825.5178  6027.8080  86.803690  1600.0  ...         0.714286
# 3  3733.3088  6548.8690  65.800150  1600.0  ...         0.714286
# 4  5258.2637  5971.4727  69.412056  1600.0  ...         0.714286
#
#    safety_zone_radius  map_name  team_size  num_players  ranking  \
# 0            3.164337       3.0          4          128      1.0
# ...

# %%
display(df3_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time   player_id   player_name  team_id  \
# 0  match_1079        79      0.444496  pid_102276    pname_2628       26
# 1  match_1079        79      0.444496   pid_52947   pname_93963       26
# 2  match_1407        72      0.405588   pid_96032   pname_14889        2
# 3  match_1079        79      0.444496    pid_5874  pname_101759       15
# 4  match_1079        79      0.444496   pid_28774   pname_79818        3
#
#        loc_x      loc_y    loc_z  health  ...  num_alive_teams  \
# 0  3069.4556  4836.6475   7.4831   100.0  ...         0.548387
# 1  3102.9702  4847.6220   5.9250   100.0  ...         0.548387
# 2  2330.1860  1018.3128  14.0384   100.0  ...         0.775862
# 3  2559.1516  3245.3428  65.1977    92.0  ...         0.548387
# 4  4808.1770  3567.1938  31.1075   100.0  ...         0.548387
#
#    safety_zone_radius  map_name  team_size  num_players   ranking  \
# 0            1.224588       0.0          4           99  0.897959
# ...

# %%
display(df4_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time  player_id  player_name  team_id  \
# 0   match_432        91      0.511116  pid_54501  pname_83248        4
# 1   match_432        91      0.511116  pid_29570   pname_1200        6
# 2  match_1600        94      0.527778  pid_68995  pname_22267        0
# 3  match_1600        94      0.527778  pid_46091  pname_22267        0
# 4   match_432        91      0.511116  pid_42731  pname_16189        3
#
#        loc_x     loc_y      loc_z  health  ...  num_alive_teams  \
# 0  3982.3088  4488.133  48.750800   100.0  ...         0.545455
# 1  3423.0770  4302.976  52.243500   100.0  ...         0.545455
# 2  3853.4763  6088.564  82.407690  1600.0  ...         0.322581
# 3  6326.6740  5836.094  69.932076  1600.0  ...         0.322581
# 4  4015.3252  3404.694  96.793304    79.0  ...         0.545455
#
#    safety_zone_radius  map_name  team_size  num_players  ranking  \
# 0            1.120348       3.0          4          126    0.528
# ...

# %%
display(df5_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time   player_id   player_name  team_id  \
# 0  match_2243        49      0.279550   pid_92376   pname_96754        4
# 1  match_2243        48      0.275023   pid_92376   pname_96754        4
# 2  match_1322       110      0.616667  pid_107617   pname_41663       27
# 3  match_1322       116      0.650017  pid_107328   pname_89609       23
# 4  match_1322       116      0.650017   pid_83416  pname_107091       27
#
#        loc_x      loc_y   loc_z      health  ...  num_alive_teams  \
# 0  2847.7156  4761.1790  6.4334   77.041756  ...         0.000000
# 1  2847.7156  4761.1790  6.4334   75.041756  ...         0.000000
# 2  6149.4220  2583.4630  5.9864  100.000000  ...         0.400000
# 3  5702.9020  2523.1401  1.8465   85.192180  ...         0.333333
# 4  6174.3413  2593.2646  6.1142  100.000000  ...         0.333333
#
#    safety_zone_radius  map_name  team_size  num_players   ranking  \
# ...

# %%
display(df6_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time  player_id  player_name  team_id  \
# 0  match_2486       127      0.711138  pid_51102   pname_4841        3
# 1  match_2486       127      0.711138  pid_68826   pname_6704        7
# 2  match_1335       132      0.738976   pid_9990  pname_22267        0
# 3  match_1335       131      0.733336  pid_88538  pname_22267        0
# 4  match_1335       132      0.738976  pid_46091  pname_22267        0
#
#        loc_x      loc_y     loc_z      health  ...  num_alive_teams  \
# 0  3254.1138  6944.7495   2.89680    98.00000  ...         0.225806
# 1  3416.1611  7170.8945  -3.69150   100.00000  ...         0.225806
# 2  3755.3447  6475.3550  69.71747   -14.00000  ...         0.161290
# 3  5242.0940  5907.4795  72.55378  1600.00000  ...         0.161290
# 4  3708.2932  6568.1387  64.45257   -13.38269  ...         0.161290
#
#    safety_zone_radius  map_name  team_size  num_players   ranking  \
# ...

# %%
display(df7_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time  player_id   player_name  team_id  \
# 0  match_2384       144      0.805646  pid_95825   pname_22267        0
# 1  match_2024       142      0.794457  pid_51079   pname_22267        0
# 2  match_2024       143      0.800005  pid_26480   pname_75202       18
# 3  match_2024       143      0.800005  pid_55331  pname_110737       22
# 4  match_2384       144      0.805646  pid_22043   pname_22267        0
#
#        loc_x      loc_y       loc_z  health  ...  num_alive_teams  \
# 0  6427.3850  4972.6895   49.979904  1600.0  ...         0.178571
# 1  4745.5063  3597.1057  110.689180  1600.0  ...         0.166667
# 2  3252.4285  5023.2470   60.597600    95.0  ...         0.166667
# 3  3107.4377  5102.8330   66.929300   100.0  ...         0.166667
# 4  5258.4214  1401.1672   95.788440  1600.0  ...         0.178571
#
#    safety_zone_radius  map_name  team_size  num_players  ranking  \
# 0            0.127536       3.0          4          127    1.000
# ...

# %%
display(df8_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time   player_id  player_name  team_id  \
# 0    match_20       153      0.855574   pid_21579  pname_19108   100009
# 1    match_20       153      0.855574  pid_105753  pname_46895   100012
# 2  match_2307       155      0.866791    pid_2720  pname_22267        0
# 3  match_2307       155      0.866791   pid_68995  pname_22267        0
# 4  match_2307       155      0.866791   pid_93436  pname_22267        0
#
#        loc_x      loc_y      loc_z  health  ...  num_alive_teams  \
# 0  4546.1724  2573.4660  30.705568   100.0  ...         0.040000
# 1  4502.7695  2576.4966  30.323800   100.0  ...         0.040000
# 2  3805.0210  6177.7607  82.547160  1600.0  ...         0.035714
# 3  3711.4763  6563.8125  64.540860  1600.0  ...         0.035714
# 4  5202.0230  5889.1380  77.679720  1600.0  ...         0.035714
#
#    safety_zone_radius  map_name  team_size  num_players   ranking  \
# 0            0.063562      10.0          1           99  1.000000
# ...

# %%
display(df9_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time  player_id   player_name  team_id  \
# 0  match_1439       142      0.796827  pid_33939   pname_77386       17
# 1  match_1439       142      0.796827  pid_97592  pname_109061       17
# 2   match_757       161      0.900049  pid_28238   pname_17235        3
# 3   match_757       161      0.900049  pid_53857   pname_96118        3
# 4  match_1439       142      0.796827  pid_51711   pname_55799       17
#
#        loc_x      loc_y   loc_z  health  ...  num_alive_teams  \
# 0  1970.7072  2749.3271  1.6959   75.00  ...         0.028571
# 1  1981.5027  2752.2422  2.3696   80.45  ...         0.028571
# 2  5983.7340  2494.0918  1.1906  100.00  ...         0.066667
# 3  5962.6655  2498.8380  0.9106  100.00  ...         0.066667
# 4  1970.7701  2750.2770  1.6422    0.00  ...         0.028571
#
#    safety_zone_radius  map_name  team_size  num_players  ranking  \
# 0            0.038223       8.0          4           96      1.0
# ...

# %%
display(df10_skillChallenge.head())
# Out:
#      match_id  snapshot  elapsed_time  player_id  player_name  team_id  \
# 0  match_2207       187      1.044666  pid_68275  pname_26190        6
# 1  match_2207       187      1.044666  pid_79458   pname_3675        6
# 2   match_281       170      0.950219  pid_93436  pname_22267        0
# 3  match_2207       185      1.033341  pid_18131  pname_23837       11
# 4  match_2207       189      1.056781  pid_25663  pname_29519        6
#
#        loc_x      loc_y      loc_z   health  ...  num_alive_teams  \
# 0  3964.2075  5754.1360  22.753700    75.00  ...         0.066667
# 1  3994.8997  5743.9660  18.294500    51.63  ...         0.066667
# 2  6251.2640  5968.6430  74.506620  1600.00  ...         0.031250
# 3  4000.8503  5747.5650  18.325900     0.00  ...         0.133333
# 4  3964.9890  5776.9883  18.659399    86.00  ...         0.000000
#
#    safety_zone_radius  map_name  team_size  num_players   ranking  \
# 0            0.049355       6.0          4           50  1.000000
# ...
