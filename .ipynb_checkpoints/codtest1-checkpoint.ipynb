# %%
import numpy as np # Handling numbers
import pandas as pd # Handling dataset
import dtale # Better stdout of dataframes
from sklearn.impute import SimpleImputer # Handling missing data
from sklearn.compose import ColumnTransformer # Encode categorical data to discrete values
from sklearn.preprocessing import LabelEncoder, OneHotEncoder # Encoding categorical data
from sklearn.model_selection import train_test_split # Splitting training and testing data
from sklearn.preprocessing import StandardScaler # Feature scaling

# %%
cod_ds = pd.read_csv("C:\\Users\\Owner\\Desktop\\Comp Sci Year 3\\CS3072 Final Year Project\\archive\\cod.csv")
dateset = dtale.show(cod_ds, notebook=True, port=40001)
print(dateset.main_url())  #%%
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-F9337VH:40000/dtale/iframe/10"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# http://DESKTOP-F9337VH:40000/dtale/main/10
# None
